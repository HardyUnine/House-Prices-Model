# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Load the dataset
df = pd.read_csv("../data/raw/new_train.csv")  # Adjust path if needed

# Top 6 most correlated numeric features with SalePrice
top_features = [
    "OverallQual", "GrLivArea", "GarageCars", 
    "GarageArea", "TotalBsmtSF", "1stFlrSF"
]

# Create a working DataFrame
df_selected = df[top_features + ["SalePrice"]].copy()

# %%
# Convert to binary based on median split
for col in top_features:
    median = df_selected[col].median()
    df_selected[col + "_bin"] = (df_selected[col] > median).astype(int)

# Rename column that starts with a digit (not allowed in formulas)
df_selected = df_selected.rename(columns={"1stFlrSF_bin": "FirstFlr_bin"})

# Define final list of binary features
binary_features = [
    "OverallQual_bin", "GrLivArea_bin", "GarageCars_bin", 
    "GarageArea_bin", "TotalBsmtSF_bin", "FirstFlr_bin"
]

# %%
# Define formula for full 2^6 factorial ANOVA (main effects + all interactions)
formula = "SalePrice ~ " + " * ".join(binary_features)

# Fit the model
model = smf.ols(formula=formula, data=df_selected).fit()

# Get the ANOVA table
anova_table = sm.stats.anova_lm(model, typ=2)

# Sort by significance (lowest p-values first)
anova_sorted = anova_table.sort_values("PR(>F)")

# Ensure full table is shown
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Display the full ANOVA table
print("\nANOVA Results (Full 2^6 Factorial Design):\n")
print(anova_sorted)
# Out:
# ANOVA Results (Full 2^6 Factorial Design):
#
#                                                                                                 sum_sq  \
# OverallQual_bin                                                                           5.268407e+11
# GrLivArea_bin                                                                             4.512192e+11
# GarageCars_bin                                                                            2.614531e+11
# TotalBsmtSF_bin                                                                           6.803582e+10
# GarageArea_bin                                                                            6.245784e+10
# FirstFlr_bin                                                                              3.714935e+10
# OverallQual_bin:FirstFlr_bin                                                              1.886390e+10
# GarageArea_bin:FirstFlr_bin                                                               1.045874e+10
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                 8.719748e+09
# OverallQual_bin:GrLivArea_bin                                                             8.241740e+09
# OverallQual_bin:GrLivArea_bin:FirstFlr_bin                                                7.993074e+09
# GarageArea_bin:TotalBsmtSF_bin                                                            7.780205e+09
# OverallQual_bin:GarageArea_bin:FirstFlr_bin                                               7.503028e+09
# GrLivArea_bin:TotalBsmtSF_bin                                                             5.427420e+09
# GarageCars_bin:GarageArea_bin                                                             5.250086e+09
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                               4.758481e+09
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                4.505733e+09
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                  4.284276e+09
# OverallQual_bin:TotalBsmtSF_bin:FirstFlr_bin                                              4.035527e+09
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                                             4.011807e+09
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                 3.916757e+09
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                               2.846045e+09
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin               2.827460e+09
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                2.194363e+09
# GrLivArea_bin:GarageArea_bin                                                              2.004780e+09
# GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                                 1.346673e+09
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                                              1.313289e+09
# GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                               1.211781e+09
# GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                                1.196956e+09
# OverallQual_bin:GrLivArea_bin:GarageArea_bin                                              1.113311e+09
# GrLivArea_bin:FirstFlr_bin                                                                9.659083e+08
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                 9.650187e+08
# TotalBsmtSF_bin:FirstFlr_bin                                                              6.596851e+08
# OverallQual_bin:TotalBsmtSF_bin                                                           4.827273e+08
# GrLivArea_bin:GarageCars_bin:GarageArea_bin                                               2.250315e+08
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin  6.013111e+07
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                              5.172625e+07
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                  5.036335e+07
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                 1.273384e+07
# OverallQual_bin:GarageArea_bin                                                            4.791802e+06
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin                               2.941992e+06
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin                                             3.003525e+05
# GarageCars_bin:GarageArea_bin:FirstFlr_bin                                                2.278270e-02
# OverallQual_bin:GarageCars_bin                                                            1.405354e-02
# GarageCars_bin:FirstFlr_bin                                                               1.313093e-02
# OverallQual_bin:GrLivArea_bin:GarageCars_bin                                              3.082612e-03
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                               2.554200e-04
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                1.781937e-07
# OverallQual_bin:GarageCars_bin:GarageArea_bin                                            -1.540472e-04
# GarageCars_bin:TotalBsmtSF_bin                                                           -1.162758e-02
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                 4.038495e-05
# OverallQual_bin:GarageCars_bin:FirstFlr_bin                                              -3.174471e-04
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin                                            1.609290e-08
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                              6.794971e-07
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin                                           -8.426465e-05
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                  9.864571e-05
# OverallQual_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                6.895638e-05
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                             1.367360e-05
# GrLivArea_bin:GarageCars_bin                                                             -9.187721e-03
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                -2.974816e-03
# GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                                -1.136470e-03
# GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                              -1.063242e-03
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                                             -8.651395e-05
# Residual                                                                                  2.736293e+12
#
#                                                                                               df  \
# OverallQual_bin                                                                              1.0
# GrLivArea_bin                                                                                1.0
# GarageCars_bin                                                                               1.0
# TotalBsmtSF_bin                                                                              1.0
# GarageArea_bin                                                                               1.0
# FirstFlr_bin                                                                                 1.0
# OverallQual_bin:FirstFlr_bin                                                                 1.0
# GarageArea_bin:FirstFlr_bin                                                                  1.0
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                    1.0
# OverallQual_bin:GrLivArea_bin                                                                1.0
# OverallQual_bin:GrLivArea_bin:FirstFlr_bin                                                   1.0
# GarageArea_bin:TotalBsmtSF_bin                                                               1.0
# OverallQual_bin:GarageArea_bin:FirstFlr_bin                                                  1.0
# GrLivArea_bin:TotalBsmtSF_bin                                                                1.0
# GarageCars_bin:GarageArea_bin                                                                1.0
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                                  1.0
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                   1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                     1.0
# OverallQual_bin:TotalBsmtSF_bin:FirstFlr_bin                                                 1.0
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                                                1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                    1.0
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                  1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                  1.0
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                   1.0
# GrLivArea_bin:GarageArea_bin                                                                 1.0
# GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                                    1.0
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                                                 1.0
# GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                                  1.0
# GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                                   1.0
# OverallQual_bin:GrLivArea_bin:GarageArea_bin                                                 1.0
# GrLivArea_bin:FirstFlr_bin                                                                   1.0
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                    1.0
# TotalBsmtSF_bin:FirstFlr_bin                                                                 1.0
# OverallQual_bin:TotalBsmtSF_bin                                                              1.0
# GrLivArea_bin:GarageCars_bin:GarageArea_bin                                                  1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin     1.0
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                                 1.0
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                     1.0
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                    1.0
# OverallQual_bin:GarageArea_bin                                                               1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin                                  1.0
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin                                                1.0
# GarageCars_bin:GarageArea_bin:FirstFlr_bin                                                   1.0
# OverallQual_bin:GarageCars_bin                                                               1.0
# GarageCars_bin:FirstFlr_bin                                                                  1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin                                                 1.0
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                  1.0
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                   1.0
# OverallQual_bin:GarageCars_bin:GarageArea_bin                                                1.0
# GarageCars_bin:TotalBsmtSF_bin                                                               1.0
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                    1.0
# OverallQual_bin:GarageCars_bin:FirstFlr_bin                                                  1.0
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin                                               1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                                 1.0
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin                                               1.0
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                     1.0
# OverallQual_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                   1.0
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                                1.0
# GrLivArea_bin:GarageCars_bin                                                                 1.0
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                    1.0
# GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                                    1.0
# GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                                  1.0
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                                                 1.0
# Residual                                                                                  1417.0
#
#                                                                                                      F  \
# OverallQual_bin                                                                           2.728265e+02
# GrLivArea_bin                                                                             2.336656e+02
# GarageCars_bin                                                                            1.353945e+02
# TotalBsmtSF_bin                                                                           3.523261e+01
# GarageArea_bin                                                                            3.234403e+01
# FirstFlr_bin                                                                              1.923793e+01
# OverallQual_bin:FirstFlr_bin                                                              9.768743e+00
# GarageArea_bin:FirstFlr_bin                                                               5.416100e+00
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                 4.515556e+00
# OverallQual_bin:GrLivArea_bin                                                             4.268017e+00
# OverallQual_bin:GrLivArea_bin:FirstFlr_bin                                                4.139245e+00
# GarageArea_bin:TotalBsmtSF_bin                                                            4.029009e+00
# OverallQual_bin:GarageArea_bin:FirstFlr_bin                                               3.885472e+00
# GrLivArea_bin:TotalBsmtSF_bin                                                             2.810611e+00
# GarageCars_bin:GarageArea_bin                                                             2.718777e+00
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                               2.464198e+00
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                2.333311e+00
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                  2.218629e+00
# OverallQual_bin:TotalBsmtSF_bin:FirstFlr_bin                                              2.089813e+00
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                                             2.077530e+00
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                 2.028308e+00
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                               1.473836e+00
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin               1.464211e+00
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                1.136360e+00
# GrLivArea_bin:GarageArea_bin                                                              1.038183e+00
# GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                                 6.973800e-01
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                                              6.800917e-01
# GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                               6.275257e-01
# GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                                6.198482e-01
# OverallQual_bin:GrLivArea_bin:GarageArea_bin                                              5.765324e-01
# GrLivArea_bin:FirstFlr_bin                                                                5.001994e-01
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                 4.997387e-01
# TotalBsmtSF_bin:FirstFlr_bin                                                              3.416205e-01
# OverallQual_bin:TotalBsmtSF_bin                                                           2.499822e-01
# GrLivArea_bin:GarageCars_bin:GarageArea_bin                                               1.165334e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin  3.113913e-02
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                              2.678664e-02
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                  2.608086e-02
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                 6.594269e-03
# OverallQual_bin:GarageArea_bin                                                            2.481453e-03
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin                               1.523522e-03
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin                                             1.555387e-04
# GarageCars_bin:GarageArea_bin:FirstFlr_bin                                                1.179811e-11
# OverallQual_bin:GarageCars_bin                                                            7.277682e-12
# GarageCars_bin:FirstFlr_bin                                                               6.799905e-12
# OverallQual_bin:GrLivArea_bin:GarageCars_bin                                              1.596343e-12
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                               1.322703e-13
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                9.227828e-17
# OverallQual_bin:GarageCars_bin:GarageArea_bin                                            -7.977392e-14
# GarageCars_bin:TotalBsmtSF_bin                                                           -6.021386e-12
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                 2.091350e-14
# OverallQual_bin:GarageCars_bin:FirstFlr_bin                                              -1.643912e-13
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin                                            8.333771e-18
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                              3.518802e-16
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin                                           -4.363677e-14
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                  5.108407e-14
# OverallQual_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                3.570933e-14
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                             7.080926e-15
# GrLivArea_bin:GarageCars_bin                                                             -4.757897e-12
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                -1.540520e-12
# GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                                -5.885255e-13
# GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                              -5.506039e-13
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                                             -4.480158e-14
# Residual                                                                                           NaN
#
#                                                                                                 PR(>F)
# OverallQual_bin                                                                           3.467197e-56
# GrLivArea_bin                                                                             6.066491e-49
# GarageCars_bin                                                                            5.933132e-30
# TotalBsmtSF_bin                                                                           3.673547e-09
# GarageArea_bin                                                                            1.566400e-08
# FirstFlr_bin                                                                              1.239293e-05
# OverallQual_bin:FirstFlr_bin                                                              1.811079e-03
# GarageArea_bin:FirstFlr_bin                                                               2.009217e-02
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                 3.376062e-02
# OverallQual_bin:GrLivArea_bin                                                             3.901764e-02
# OverallQual_bin:GrLivArea_bin:FirstFlr_bin                                                4.208573e-02
# GarageArea_bin:TotalBsmtSF_bin                                                            4.491380e-02
# OverallQual_bin:GarageArea_bin:FirstFlr_bin                                               4.889989e-02
# GrLivArea_bin:TotalBsmtSF_bin                                                             9.386331e-02
# GarageCars_bin:GarageArea_bin                                                             9.939561e-02
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                               1.166904e-01
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                1.268554e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                  1.365766e-01
# OverallQual_bin:TotalBsmtSF_bin:FirstFlr_bin                                              1.485053e-01
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                                             1.497029e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                 1.546126e-01
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                               2.249438e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin               2.264631e-01
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                2.866045e-01
# GrLivArea_bin:GarageArea_bin                                                              3.084184e-01
# GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                                 4.038062e-01
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                                              4.096939e-01
# GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                               4.283970e-01
# GrLivArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                                4.312354e-01
# OverallQual_bin:GrLivArea_bin:GarageArea_bin                                              4.478010e-01
# GrLivArea_bin:FirstFlr_bin                                                                4.795288e-01
# GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                 4.797312e-01
# TotalBsmtSF_bin:FirstFlr_bin                                                              5.589884e-01
# OverallQual_bin:TotalBsmtSF_bin                                                           6.171652e-01
# GrLivArea_bin:GarageCars_bin:GarageArea_bin                                               7.328757e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin  8.599556e-01
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:TotalBsmtSF_bin                              8.700172e-01
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                  8.717260e-01
# OverallQual_bin:GrLivArea_bin:GarageArea_bin:FirstFlr_bin                                 9.352903e-01
# OverallQual_bin:GarageArea_bin                                                            9.602775e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:GarageArea_bin                               9.688701e-01
# OverallQual_bin:GrLivArea_bin:TotalBsmtSF_bin                                             9.900512e-01
# GarageCars_bin:GarageArea_bin:FirstFlr_bin                                                9.999973e-01
# OverallQual_bin:GarageCars_bin                                                            9.999979e-01
# GarageCars_bin:FirstFlr_bin                                                               9.999979e-01
# OverallQual_bin:GrLivArea_bin:GarageCars_bin                                              9.999990e-01
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                               9.999997e-01
# GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin:FirstFlr_bin                                1.000000e+00
# OverallQual_bin:GarageCars_bin:GarageArea_bin                                             1.000000e+00
# GarageCars_bin:TotalBsmtSF_bin                                                            1.000000e+00
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                 1.000000e+00
# OverallQual_bin:GarageCars_bin:FirstFlr_bin                                               1.000000e+00
# OverallQual_bin:GarageCars_bin:TotalBsmtSF_bin                                            1.000000e+00
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                              1.000000e+00
# OverallQual_bin:GarageArea_bin:TotalBsmtSF_bin                                            1.000000e+00
# GrLivArea_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                  1.000000e+00
# OverallQual_bin:GarageCars_bin:GarageArea_bin:FirstFlr_bin                                1.000000e+00
# OverallQual_bin:GarageCars_bin:GarageArea_bin:TotalBsmtSF_bin                             1.000000e+00
# GrLivArea_bin:GarageCars_bin                                                              1.000000e+00
# OverallQual_bin:GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                 1.000000e+00
# GrLivArea_bin:GarageCars_bin:FirstFlr_bin                                                 1.000000e+00
# GarageCars_bin:TotalBsmtSF_bin:FirstFlr_bin                                               1.000000e+00
# GrLivArea_bin:GarageCars_bin:TotalBsmtSF_bin                                              1.000000e+00
# Residual                                                                                           NaN
